# %%
import torch
from torch.utils.data import DataLoader
from torchvision.datasets import MNIST
from torchvision import transforms
from torch import optim
import torch.nn as nn
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.gridspec as gridspec

# %%
def showing(images,count):
    images=images.detach().numpy()[0:16,:]
    images=255*(0.5*images+0.5)
    images = images.astype(np.uint8)
    grid_length=int(np.ceil(np.sqrt(images.shape[0])))
    plt.figure(figsize=(4,4))
    width = int(np.sqrt((images.shape[1])))
    gs = gridspec.GridSpec(grid_length,grid_length,wspace=0,hspace=0)
    # gs.update(wspace=0, hspace=0)
    print('starting...')
    for i, img in enumerate(images):
        ax = plt.subplot(gs[i])
        ax.set_xticklabels([])
        ax.set_yticklabels([])
        ax.set_aspect('equal')
        plt.imshow(img.reshape([width,width]),cmap = plt.cm.gray)
        plt.axis('off')
        plt.tight_layout()
    print('showing...')
    plt.tight_layout()
    plt.savefig('./GAN_Image/%d.png'%count, bbox_inches='tight')

# %%
batch_size=100
num_epoch=100
z_dimension=100
trans_img=transforms.Compose([transforms.ToTensor()])
trainset=MNIST('./data',train=True,transform=trans_img,download=True)
testset=MNIST('./data',train=False,transform=trans_img,download=True)
# device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
trainloader=DataLoader(trainset,batch_size=batch_size,shuffle=True,num_workers=10)
testloader= DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=10)

# %%
class discriminator(nn.Module):
    def __init__(self):
        super(discriminator,self).__init__()
        self.dis=nn.Sequential(
            nn.Linear(784,256),
            nn.LeakyReLU(0.2),
            nn.Linear(256,256),
            nn.LeakyReLU(0.2),
            nn.Linear(256,1),
            nn.Sigmoid()

        )
    def forward(self,x):
        x=self.dis(x)
        return x

# %%
class generator(nn.Module):
    def __init__(self,input_size):
        super(generator,self).__init__()
        self.gen=nn.Sequential(
            nn.Linear(input_size,256),
            nn.ReLU(True),
            nn.Linear(256,256),
            nn.ReLU(True),
            nn.Linear(256,784),
            nn.Tanh()

        )
    def forward(self, x):
        x=self.gen(x)
        return x

# %%
    D=discriminator()
    G=generator(z_dimension)
    criterion=nn.BCELoss() # Binary Cross Entropy 二分类的交叉损失商
    num_img=100
    d_optimizer=torch.optim.Adam(D.parameters(),lr=0.0003)
    g_optimizer=torch.optim.Adam(G.parameters(),lr=0.0003)
    count=0
    epoch=100
    gepoch=1
    for i in range(epoch):
        for (img,label) in trainloader:
            real_img=img.view(num_img,-1)
            real_label=torch.ones(num_img)
            fake_label=torch.zeros(num_img)

        
            real_out=D(real_img)
            d_loss_real=criterion(real_out,real_label)
            real_scores=real_out

            z=torch.randn(num_img,z_dimension)
            fake_img=G(z)
            fake_out=D(fake_img)
            d_loss_fake=criterion(fake_out,fake_label)
            fake_scores=fake_out

            d_loss=d_loss_real+d_loss_fake
            d_optimizer.zero_grad()
            d_loss.backward()
            d_optimizer.step()

            for j in range(gepoch):
                fake_label=torch.ones(num_img)
                z=torch.randn(num_img,z_dimension)
                fake_img=G(z)
                output=D(fake_img)
                g_loss=criterion(output,fake_label)
                g_optimizer.zero_grad()
                g_loss.backward()
                g_optimizer.step()
        print('Epoch [{}/{}],d_loss:{:.6f},g_loss:{:.6f}''D real: {:.6f}, D fake: {:.6f}'.format(
            i,epoch,d_loss.item(),g_loss.item(),real_scores.data.mean(),
            fake_scores.data.mean()
            ))
        showing(fake_img,count)
        plt.show()
        count+=1
# Out:
# Epoch [0/100],d_loss:0.562994,g_loss:3.306428D real: 0.853901, D fake: 0.248733
# starting...
# showing...
# Epoch [1/100],d_loss:0.796687,g_loss:2.064205D real: 0.714516, D fake: 0.310228
# starting...
# showing...
# Epoch [2/100],d_loss:0.101740,g_loss:3.192158D real: 0.980728, D fake: 0.074868
# starting...
# showing...
# Epoch [3/100],d_loss:0.087860,g_loss:5.063300D real: 0.971268, D fake: 0.023270
# starting...
# showing...
# Epoch [4/100],d_loss:0.171583,g_loss:5.449327D real: 0.956025, D fake: 0.069963
# starting...
# showing...
# Epoch [5/100],d_loss:0.436986,g_loss:6.106860D real: 0.862400, D fake: 0.090491
# starting...
# showing...
# Epoch [6/100],d_loss:0.297526,g_loss:4.368543D real: 0.928357, D fake: 0.128890
# starting...
# showing...
# Epoch [7/100],d_loss:0.329055,g_loss:8.733107D real: 0.879042, D fake: 0.018983
# starting...
# showing...
# Epoch [8/100],d_loss:0.263618,g_loss:6.104800D real: 0.953192, D fake: 0.102734
# starting...
# showing...
# Epoch [9/100],d_loss:0.191707,g_loss:4.705305D real: 0.939213, D fake: 0.037248
# starting...
# showing...
# Epoch [10/100],d_loss:0.268384,g_loss:7.245472D real: 0.899458, D fake: 0.051301
# starting...
# showing...
# Epoch [11/100],d_loss:0.270963,g_loss:5.028226D real: 0.908717, D fake: 0.059095
# starting...
# showing...
# Epoch [12/100],d_loss:0.096926,g_loss:6.213892D real: 0.952258, D fake: 0.017842
# starting...
# showing...
# Epoch [13/100],d_loss:0.286244,g_loss:6.333925D real: 0.944691, D fake: 0.108586
# starting...
# showing...
# Epoch [14/100],d_loss:0.145778,g_loss:5.325964D real: 0.951242, D fake: 0.034322
# starting...
# showing...
# Epoch [15/100],d_loss:0.352578,g_loss:4.855714D real: 0.898046, D fake: 0.068531
# starting...
# showing...
# Epoch [16/100],d_loss:0.075288,g_loss:5.115795D real: 0.969257, D fake: 0.030737
# starting...
# showing...
# Epoch [17/100],d_loss:0.147437,g_loss:6.431667D real: 0.967162, D fake: 0.064363
# starting...
# showing...
# Epoch [18/100],d_loss:0.062146,g_loss:5.708740D real: 0.969772, D fake: 0.016173
# starting...
# showing...
# Epoch [19/100],d_loss:0.131513,g_loss:5.311471D real: 0.971128, D fake: 0.073286
# starting...
# showing...
# Epoch [20/100],d_loss:0.117623,g_loss:8.710034D real: 0.972346, D fake: 0.025862
# starting...
# showing...
# Epoch [21/100],d_loss:0.156925,g_loss:6.481352D real: 0.947175, D fake: 0.034322
# starting...
# showing...
# Epoch [22/100],d_loss:0.105506,g_loss:6.371589D real: 0.961315, D fake: 0.028105
# starting...
# showing...
# Epoch [23/100],d_loss:0.045918,g_loss:7.364829D real: 0.982752, D fake: 0.018195
# starting...
# showing...
# Epoch [24/100],d_loss:0.107361,g_loss:6.996729D real: 0.958797, D fake: 0.004018
# starting...
# showing...
# Epoch [25/100],d_loss:0.075948,g_loss:5.398794D real: 0.980919, D fake: 0.031868
# starting...
# showing...
# Epoch [26/100],d_loss:0.034717,g_loss:5.870433D real: 0.997141, D fake: 0.028898
# starting...
# showing...
# Epoch [27/100],d_loss:0.082385,g_loss:7.151616D real: 0.970665, D fake: 0.014759
# starting...
# showing...
# Epoch [28/100],d_loss:0.208148,g_loss:7.714462D real: 0.985108, D fake: 0.091141
# starting...
# showing...
# Epoch [29/100],d_loss:0.167340,g_loss:7.681421D real: 0.958427, D fake: 0.060290
# starting...
# showing...
# Epoch [30/100],d_loss:0.151804,g_loss:6.535272D real: 0.960200, D fake: 0.049350
# starting...
# showing...
# Epoch [31/100],d_loss:0.058597,g_loss:5.985129D real: 0.977366, D fake: 0.020872
# starting...
# showing...
# Epoch [32/100],d_loss:0.081798,g_loss:7.701118D real: 0.974240, D fake: 0.018159
# starting...
# showing...
# Epoch [33/100],d_loss:0.050649,g_loss:7.632313D real: 0.970273, D fake: 0.009605
# starting...
# showing...
# Epoch [34/100],d_loss:0.094081,g_loss:6.025187D real: 0.974574, D fake: 0.028975
# starting...
# showing...
# Epoch [35/100],d_loss:0.231262,g_loss:8.437678D real: 0.932131, D fake: 0.022159
# starting...
# showing...
# Epoch [36/100],d_loss:0.109403,g_loss:7.188725D real: 0.973601, D fake: 0.051601
# starting...
# showing...
# Epoch [37/100],d_loss:0.050711,g_loss:7.473059D real: 0.973774, D fake: 0.015945
# starting...
# showing...
# Epoch [38/100],d_loss:0.186305,g_loss:8.326539D real: 0.977168, D fake: 0.085132
# starting...
# showing...
# Process Process-549:
# Process Process-548:
# Process Process-550:
# Process Process-545:
# Process Process-546:
# Process Process-542:
# Process Process-547:
# Process Process-541:
# Process Process-543:
# Process Process-544:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/anaconda2/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-93-7ff97546cbab> in <module>
#      38             g_optimizer.zero_grad()
#      39             g_loss.backward()
# ---> 40             g_optimizer.step()
#      41     print('Epoch [{}/{}],d_loss:{:.6f},g_loss:{:.6f}''D real: {:.6f}, D fake: {:.6f}'.format(
#      42         i,epoch,d_loss.item(),g_loss.item(),real_scores.data.mean(),
#
# /anaconda2/envs/pytorch/lib/python3.6/site-packages/torch/optim/adam.py in step(self, closure)
#      90
#      91                 # Decay the first and second moment running average coefficient
# ---> 92                 exp_avg.mul_(beta1).add_(1 - beta1, grad)
#      93                 exp_avg_sq.mul_(beta2).addcmul_(1 - beta2, grad, grad)
#      94                 if amsgrad:
#
# KeyboardInterrupt:
#   File "/anaconda2/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/anaconda2/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/anaconda2/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/anaconda2/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/anaconda2/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/anaconda2/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/anaconda2/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/anaconda2/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/anaconda2/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/anaconda2/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/anaconda2/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/anaconda2/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/anaconda2/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/anaconda2/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/anaconda2/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/anaconda2/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/anaconda2/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/anaconda2/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/anaconda2/envs/pytorch/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/anaconda2/envs/pytorch/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 96, in _worker_loop
#     r = index_queue.get(timeout=MANAGER_STATUS_CHECK_INTERVAL)
#   File "/anaconda2/envs/pytorch/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 96, in _worker_loop
#     r = index_queue.get(timeout=MANAGER_STATUS_CHECK_INTERVAL)
#   File "/anaconda2/envs/pytorch/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 96, in _worker_loop
#     r = index_queue.get(timeout=MANAGER_STATUS_CHECK_INTERVAL)
#   File "/anaconda2/envs/pytorch/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 96, in _worker_loop
#     r = index_queue.get(timeout=MANAGER_STATUS_CHECK_INTERVAL)
#   File "/anaconda2/envs/pytorch/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 96, in _worker_loop
#     r = index_queue.get(timeout=MANAGER_STATUS_CHECK_INTERVAL)
#   File "/anaconda2/envs/pytorch/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 96, in _worker_loop
#     r = index_queue.get(timeout=MANAGER_STATUS_CHECK_INTERVAL)
#   File "/anaconda2/envs/pytorch/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 96, in _worker_loop
#     r = index_queue.get(timeout=MANAGER_STATUS_CHECK_INTERVAL)
#   File "/anaconda2/envs/pytorch/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 96, in _worker_loop
#     r = index_queue.get(timeout=MANAGER_STATUS_CHECK_INTERVAL)
#   File "/anaconda2/envs/pytorch/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 96, in _worker_loop
#     r = index_queue.get(timeout=MANAGER_STATUS_CHECK_INTERVAL)
#   File "/anaconda2/envs/pytorch/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 96, in _worker_loop
#     r = index_queue.get(timeout=MANAGER_STATUS_CHECK_INTERVAL)
#   File "/anaconda2/envs/pytorch/lib/python3.6/multiprocessing/queues.py", line 104, in get
#     if not self._poll(timeout):
#   File "/anaconda2/envs/pytorch/lib/python3.6/multiprocessing/queues.py", line 104, in get
#     if not self._poll(timeout):
#   File "/anaconda2/envs/pytorch/lib/python3.6/multiprocessing/queues.py", line 104, in get
#     if not self._poll(timeout):
#   File "/anaconda2/envs/pytorch/lib/python3.6/multiprocessing/queues.py", line 104, in get
#     if not self._poll(timeout):
#   File "/anaconda2/envs/pytorch/lib/python3.6/multiprocessing/queues.py", line 104, in get
#     if not self._poll(timeout):
#   File "/anaconda2/envs/pytorch/lib/python3.6/multiprocessing/queues.py", line 104, in get
#     if not self._poll(timeout):
#   File "/anaconda2/envs/pytorch/lib/python3.6/multiprocessing/queues.py", line 104, in get
#     if not self._poll(timeout):
#   File "/anaconda2/envs/pytorch/lib/python3.6/multiprocessing/queues.py", line 104, in get
#     if not self._poll(timeout):
#   File "/anaconda2/envs/pytorch/lib/python3.6/multiprocessing/queues.py", line 104, in get
#     if not self._poll(timeout):
#   File "/anaconda2/envs/pytorch/lib/python3.6/multiprocessing/queues.py", line 104, in get
#     if not self._poll(timeout):
#   File "/anaconda2/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 257, in poll
#     return self._poll(timeout)
#   File "/anaconda2/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 257, in poll
#     return self._poll(timeout)
#   File "/anaconda2/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 257, in poll
#     return self._poll(timeout)
#   File "/anaconda2/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 257, in poll
#     return self._poll(timeout)
#   File "/anaconda2/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 257, in poll
#     return self._poll(timeout)
#   File "/anaconda2/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 257, in poll
#     return self._poll(timeout)
#   File "/anaconda2/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 257, in poll
#     return self._poll(timeout)
#   File "/anaconda2/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 257, in poll
#     return self._poll(timeout)
#   File "/anaconda2/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 257, in poll
#     return self._poll(timeout)
#   File "/anaconda2/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 257, in poll
#     return self._poll(timeout)
#   File "/anaconda2/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 414, in _poll
#     r = wait([self], timeout)
#   File "/anaconda2/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 414, in _poll
#     r = wait([self], timeout)
#   File "/anaconda2/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 414, in _poll
#     r = wait([self], timeout)
#   File "/anaconda2/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 414, in _poll
#     r = wait([self], timeout)
#   File "/anaconda2/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 414, in _poll
#     r = wait([self], timeout)
#   File "/anaconda2/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 414, in _poll
#     r = wait([self], timeout)
#   File "/anaconda2/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 414, in _poll
#     r = wait([self], timeout)
#   File "/anaconda2/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 414, in _poll
#     r = wait([self], timeout)
#   File "/anaconda2/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 414, in _poll
#     r = wait([self], timeout)
#   File "/anaconda2/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 414, in _poll
#     r = wait([self], timeout)
#   File "/anaconda2/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 911, in wait
#     ready = selector.select(timeout)
#   File "/anaconda2/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 911, in wait
#     ready = selector.select(timeout)
#   File "/anaconda2/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 911, in wait
#     ready = selector.select(timeout)
#   File "/anaconda2/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 911, in wait
#     ready = selector.select(timeout)
#   File "/anaconda2/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 911, in wait
#     ready = selector.select(timeout)
#   File "/anaconda2/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 911, in wait
#     ready = selector.select(timeout)
#   File "/anaconda2/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 911, in wait
#     ready = selector.select(timeout)
#   File "/anaconda2/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 911, in wait
#     ready = selector.select(timeout)
#   File "/anaconda2/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 911, in wait
#     ready = selector.select(timeout)
#   File "/anaconda2/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 911, in wait
#     ready = selector.select(timeout)
#   File "/anaconda2/envs/pytorch/lib/python3.6/selectors.py", line 376, in select
#     fd_event_list = self._poll.poll(timeout)
#   File "/anaconda2/envs/pytorch/lib/python3.6/selectors.py", line 376, in select
#     fd_event_list = self._poll.poll(timeout)
#   File "/anaconda2/envs/pytorch/lib/python3.6/selectors.py", line 376, in select
#     fd_event_list = self._poll.poll(timeout)
#   File "/anaconda2/envs/pytorch/lib/python3.6/selectors.py", line 376, in select
#     fd_event_list = self._poll.poll(timeout)
#   File "/anaconda2/envs/pytorch/lib/python3.6/selectors.py", line 376, in select
#     fd_event_list = self._poll.poll(timeout)
#   File "/anaconda2/envs/pytorch/lib/python3.6/selectors.py", line 376, in select
#     fd_event_list = self._poll.poll(timeout)
#   File "/anaconda2/envs/pytorch/lib/python3.6/selectors.py", line 376, in select
#     fd_event_list = self._poll.poll(timeout)
#   File "/anaconda2/envs/pytorch/lib/python3.6/selectors.py", line 376, in select
#     fd_event_list = self._poll.poll(timeout)
#   File "/anaconda2/envs/pytorch/lib/python3.6/selectors.py", line 376, in select
#     fd_event_list = self._poll.poll(timeout)
#   File "/anaconda2/envs/pytorch/lib/python3.6/selectors.py", line 376, in select
#     fd_event_list = self._poll.poll(timeout)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
